# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('results.csv')

# %%
df.head()
# Out:
#                                          Description     Price  \
# 0                                          Homo Deus  R$ 44,90
# 1                         21 lições para o século 21  R$ 46,90
# 2                       Breve história de quase tudo  R$ 56,90
# 3                                   Raízes do Brasil  R$ 44,19
# 4  Data science para negócios: O que você precisa...  R$ 62,90
#
#               Rating  ReviewCount  \
# 0  4,8 de 5 estrelas        7.023
# 1  4,8 de 5 estrelas        6.217
# 2  4,7 de 5 estrelas      484.000
# 3  4,8 de 5 estrelas        1.274
# 4  4,7 de 5 estrelas      657.000
#
#                                                  Url
# 0  https://www.amazon.com.br/gp/slredirect/picass...
# 1  https://www.amazon.com.br/gp/slredirect/picass...
# 2  https://www.amazon.com.br/gp/slredirect/picass...
# 3  https://www.amazon.com.br/gp/slredirect/picass...
# 4  https://www.amazon.com.br/Data-Science-para-ne...

# %%
df.describe()
# Out:
#        ReviewCount
# count   365.000000
# mean    201.964526
# std     251.904852
# min       1.071000
# 25%      12.000000
# 50%      97.000000
# 75%     281.000000
# max     927.000000

# %%
len(df)
# Out:
# 392

# %%
df['ReviewCount'].plot()
# Out:
# <AxesSubplot:>
