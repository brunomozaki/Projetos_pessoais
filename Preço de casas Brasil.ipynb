# %% [markdown]
# ## Analisando preço casas de cidades brasileiras

# %% [markdown]
# Estarei analisando preço de casas de algumas cidades brasileiras e a partir disso, criar um modelo preditivo que avalia o preço total.
# Por fim, irei plotar um mapa dos estados e estarão coloridos a partir de seus preços.
# Os dados foram obtidos no site Kaggle.
# *Vale ressaltar que os dados obtidos possuem uma certa limitação no sentido que existem poucas cidades no arquivo

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import chart_studio.plotly as py
import plotly.graph_objs as go 
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import geopandas as gpd
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cb1= pd.read_csv('houses_to_rent.csv')

# %%
cb1.head()
# Out:
#    Unnamed: 0  city  area  rooms  bathroom  parking spaces floor     animal  \
# 0           0     1   240      3         3               4     -      acept
# 1           1     0    64      2         1               1    10      acept
# 2           2     1   443      5         5               4     3      acept
# 3           3     1    73      2         2               1    12      acept
# 4           4     1    19      1         1               0     -  not acept
#
#        furniture      hoa rent amount property tax fire insurance     total
# 0      furnished      R$0     R$8,000      R$1,000          R$121   R$9,121
# 1  not furnished    R$540       R$820        R$122           R$11   R$1,493
# 2      furnished  R$4,172     R$7,000      R$1,417           R$89  R$12,680
# 3  not furnished    R$700     R$1,250        R$150           R$16   R$2,116
# 4  not furnished      R$0     R$1,200         R$41           R$16   R$1,257

# %%
cb2=pd.read_csv('houses_to_rent_v2.csv')

# %%
cb2
# Out:
#                  city  area  rooms  bathroom  parking spaces floor     animal  \
# 0           São Paulo    70      2         1               1     7      acept
# 1           São Paulo   320      4         4               0    20      acept
# 2        Porto Alegre    80      1         1               1     6      acept
# 3        Porto Alegre    51      2         1               0     2      acept
# 4           São Paulo    25      1         1               0     1  not acept
# ...               ...   ...    ...       ...             ...   ...        ...
# 10687    Porto Alegre    63      2         1               1     5  not acept
# 10688       São Paulo   285      4         4               4    17      acept
# 10689  Rio de Janeiro    70      3         3               0     8  not acept
# 10690  Rio de Janeiro   120      2         2               2     8      acept
# 10691       São Paulo    80      2         1               0     -      acept
#
#            furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 0          furnished      2065              3300                211
# 1      not furnished      1200              4960               1750
# 2      not furnished      1000              2800                  0
# 3      not furnished       270              1112                 22
# 4      not furnished         0               800                 25
# ...              ...       ...               ...                ...
# 10687      furnished       402              1478                 24
# 10688  not furnished      3100             15000                973
# 10689      furnished       980              6000                332
# 10690      furnished      1585             12000                279
# 10691  not furnished         0              1400                165
#
#        fire insurance (R$)  total (R$)
# 0                       42        5618
# 1                       63        7973
# 2                       41        3841
# 3                       17        1421
# 4                       11         836
# ...                    ...         ...
# 10687                   22        1926
# 10688                  191       19260
# 10689                   78        7390
# 10690                  155       14020
# 10691                   22        1587
#
# [10692 rows x 13 columns]

# %%
cb2.describe()
# Out:
#                area         rooms      bathroom  parking spaces      hoa (R$)  \
# count  10692.000000  10692.000000  10692.000000    10692.000000  1.069200e+04
# mean     149.217920      2.506079      2.236813        1.609147  1.174022e+03
# std      537.016942      1.171266      1.407198        1.589521  1.559231e+04
# min       11.000000      1.000000      1.000000        0.000000  0.000000e+00
# 25%       56.000000      2.000000      1.000000        0.000000  1.700000e+02
# 50%       90.000000      2.000000      2.000000        1.000000  5.600000e+02
# 75%      182.000000      3.000000      3.000000        2.000000  1.237500e+03
# max    46335.000000     13.000000     10.000000       12.000000  1.117000e+06
#
#        rent amount (R$)  property tax (R$)  fire insurance (R$)    total (R$)
# count      10692.000000       10692.000000         10692.000000  1.069200e+04
# mean        3896.247194         366.704358            53.300879  5.490487e+03
# std         3408.545518        3107.832321            47.768031  1.648473e+04
# min          450.000000           0.000000             3.000000  4.990000e+02
# 25%         1530.000000          38.000000            21.000000  2.061750e+03
# 50%         2661.000000         125.000000            36.000000  3.581500e+03
# 75%         5000.000000         375.000000            68.000000  6.768000e+03
# max        45000.000000      313700.000000           677.000000  1.120000e+06

# %%
sns.pairplot(cb2)

# %%
cb2.corr()
# Out:
#                          area     rooms  bathroom  parking spaces  hoa (R$)  \
# area                 1.000000  0.193796  0.226766        0.193983  0.006890
# rooms                0.193796  1.000000  0.733763        0.617510  0.007139
# bathroom             0.226766  0.733763  1.000000        0.697379  0.050271
# parking spaces       0.193983  0.617510  0.697379        1.000000  0.009321
# hoa (R$)             0.006890  0.007139  0.050271        0.009321  1.000000
# rent amount (R$)     0.180742  0.541758  0.668504        0.578361  0.036490
# property tax (R$)    0.039059  0.075252  0.109253        0.098378  0.007627
# fire insurance (R$)  0.188078  0.565148  0.676399        0.597348  0.029535
# total (R$)           0.051799  0.134597  0.208339        0.148684  0.955024
#
#                      rent amount (R$)  property tax (R$)  fire insurance (R$)  \
# area                         0.180742           0.039059             0.188078
# rooms                        0.541758           0.075252             0.565148
# bathroom                     0.668504           0.109253             0.676399
# parking spaces               0.578361           0.098378             0.597348
# hoa (R$)                     0.036490           0.007627             0.029535
# rent amount (R$)             1.000000           0.107884             0.987343
# property tax (R$)            0.107884           1.000000             0.105661
# fire insurance (R$)          0.987343           0.105661             1.000000
# total (R$)                   0.264490           0.218344             0.254911
#
#                      total (R$)
# area                   0.051799
# rooms                  0.134597
# bathroom               0.208339
# parking spaces         0.148684
# hoa (R$)               0.955024
# rent amount (R$)       0.264490
# property tax (R$)      0.218344
# fire insurance (R$)    0.254911
# total (R$)             1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(cb2.corr(),annot=True)

# %%
sns.scatterplot(data=cb2,y='total (R$)',x='hoa (R$)')

# %%
cb2[cb2['hoa (R$)']==1.117000e+06]
# Out:
#                 city  area  rooms  bathroom  parking spaces floor     animal  \
# 255   Belo Horizonte   155      1         4               0     4  not acept
# 6979  Belo Horizonte   155      1         4               0     4  not acept
#
#           furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 255   not furnished   1117000              2790                 64
# 6979  not furnished   1117000              2790                 64
#
#       fire insurance (R$)  total (R$)
# 255                    38     1120000
# 6979                   38     1120000

# %%
cb2.drop([255,6979],inplace=True)

# %%
sns.scatterplot(data=cb2,y='total (R$)',x='hoa (R$)')

# %% [markdown]
# Essas etapas consistem em retirar os outliers de nossos dados para que não interfiram na análise

# %%
cb2[cb2['total (R$)']==1.120000e+06]
# Out:
# Empty DataFrame
# Columns: [city, area, rooms, bathroom, parking spaces, floor, animal, furniture, hoa (R$), rent amount (R$), property tax (R$), fire insurance (R$), total (R$)]
# Index: []

# %%
cb2['total (R$)'].max()
# Out:
# 316900

# %%
cb2[cb2['total (R$)']==316900]
# Out:
#            city  area  rooms  bathroom  parking spaces floor     animal  \
# 6645  São Paulo    42      1         2               1     6  not acept
#
#           furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 6645  not furnished       690              2500             313700
#
#       fire insurance (R$)  total (R$)
# 6645                   32      316900

# %% [markdown]
# Essas etapas

# %%
cb2.drop(6645,inplace=True)

# %%
cb2[cb2['total (R$)']==233200]
# Out:
#            city  area  rooms  bathroom  parking spaces floor animal  \
# 6230  São Paulo   340      5         4               2     7  acept
#
#           furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 6230  not furnished    220000             12000               1000
#
#       fire insurance (R$)  total (R$)
# 6230                  153      233200

# %%
cb2.drop(6230,inplace=True)

# %%
cb2.drop(2859,inplace=True)

# %%
sns.distplot(cb2['total (R$)'])

# %% [markdown]
# Transformando animais e imobiliado em valores numéricos

# %%
animals = pd.get_dummies(cb2['animal'],drop_first=True)
furnitures = pd.get_dummies(cb2['furniture'],drop_first=True)

# %%
cb2.drop(['animal','furniture'],axis=1,inplace=True)

# %%
cb2
# Out:
#                  city  area  rooms  bathroom  parking spaces floor  hoa (R$)  \
# 0           São Paulo    70      2         1               1     7      2065
# 1           São Paulo   320      4         4               0    20      1200
# 2        Porto Alegre    80      1         1               1     6      1000
# 3        Porto Alegre    51      2         1               0     2       270
# 4           São Paulo    25      1         1               0     1         0
# ...               ...   ...    ...       ...             ...   ...       ...
# 10687    Porto Alegre    63      2         1               1     5       402
# 10688       São Paulo   285      4         4               4    17      3100
# 10689  Rio de Janeiro    70      3         3               0     8       980
# 10690  Rio de Janeiro   120      2         2               2     8      1585
# 10691       São Paulo    80      2         1               0     -         0
#
#        rent amount (R$)  property tax (R$)  fire insurance (R$)  total (R$)
# 0                  3300                211                   42        5618
# 1                  4960               1750                   63        7973
# 2                  2800                  0                   41        3841
# 3                  1112                 22                   17        1421
# 4                   800                 25                   11         836
# ...                 ...                ...                  ...         ...
# 10687              1478                 24                   22        1926
# 10688             15000                973                  191       19260
# 10689              6000                332                   78        7390
# 10690             12000                279                  155       14020
# 10691              1400                165                   22        1587
#
# [10687 rows x 11 columns]

# %%
cb2['no animals']= animals

# %%
cb2
# Out:
#                  city  area  rooms  bathroom  parking spaces floor  hoa (R$)  \
# 0           São Paulo    70      2         1               1     7      2065
# 1           São Paulo   320      4         4               0    20      1200
# 2        Porto Alegre    80      1         1               1     6      1000
# 3        Porto Alegre    51      2         1               0     2       270
# 4           São Paulo    25      1         1               0     1         0
# ...               ...   ...    ...       ...             ...   ...       ...
# 10687    Porto Alegre    63      2         1               1     5       402
# 10688       São Paulo   285      4         4               4    17      3100
# 10689  Rio de Janeiro    70      3         3               0     8       980
# 10690  Rio de Janeiro   120      2         2               2     8      1585
# 10691       São Paulo    80      2         1               0     -         0
#
#        rent amount (R$)  property tax (R$)  fire insurance (R$)  total (R$)  \
# 0                  3300                211                   42        5618
# 1                  4960               1750                   63        7973
# 2                  2800                  0                   41        3841
# 3                  1112                 22                   17        1421
# 4                   800                 25                   11         836
# ...                 ...                ...                  ...         ...
# 10687              1478                 24                   22        1926
# 10688             15000                973                  191       19260
# 10689              6000                332                   78        7390
# 10690             12000                279                  155       14020
# 10691              1400                165                   22        1587
#
#        no animals
# 0               0
# 1               0
# 2               0
# 3               0
# 4               1
# ...           ...
# 10687           1
# 10688           0
# 10689           1
# 10690           0
# 10691           0
#
# [10687 rows x 12 columns]

# %%
cb2['no furniture']= furnitures

# %%
cb2
# Out:
#                  city  area  rooms  bathroom  parking spaces floor  hoa (R$)  \
# 0           São Paulo    70      2         1               1     7      2065
# 1           São Paulo   320      4         4               0    20      1200
# 2        Porto Alegre    80      1         1               1     6      1000
# 3        Porto Alegre    51      2         1               0     2       270
# 4           São Paulo    25      1         1               0     1         0
# ...               ...   ...    ...       ...             ...   ...       ...
# 10687    Porto Alegre    63      2         1               1     5       402
# 10688       São Paulo   285      4         4               4    17      3100
# 10689  Rio de Janeiro    70      3         3               0     8       980
# 10690  Rio de Janeiro   120      2         2               2     8      1585
# 10691       São Paulo    80      2         1               0     -         0
#
#        rent amount (R$)  property tax (R$)  fire insurance (R$)  total (R$)  \
# 0                  3300                211                   42        5618
# 1                  4960               1750                   63        7973
# 2                  2800                  0                   41        3841
# 3                  1112                 22                   17        1421
# 4                   800                 25                   11         836
# ...                 ...                ...                  ...         ...
# 10687              1478                 24                   22        1926
# 10688             15000                973                  191       19260
# 10689              6000                332                   78        7390
# 10690             12000                279                  155       14020
# 10691              1400                165                   22        1587
#
#        no animals  no furniture
# 0               0             0
# 1               0             1
# 2               0             1
# 3               0             1
# 4               1             1
# ...           ...           ...
# 10687           1             0
# 10688           0             1
# 10689           1             0
# 10690           0             0
# 10691           0             1
#
# [10687 rows x 13 columns]

# %%
cb2.dropna(inplace=True)

# %%
cb2 = cb2[cb2!= '-']
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning:
#
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison

# %%
cb2.dropna(inplace=True)

# %% [markdown]
# ### Modelo preditivo utilizando regressão linear

# %%
X= cb2[['area','rooms','bathroom', 'parking spaces', 'floor', 'hoa (R$)', 'rent amount (R$)', 'property tax (R$)', 'fire insurance (R$)', 'no animals','no furniture']]
y= cb2['total (R$)']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lm.intercept_)
# Out:
# 0.4579728540211363

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                      Coefficient
# area                   -0.001458
# rooms                  -0.122140
# bathroom                0.252686
# parking spaces         -0.018835
# floor                  -0.039207
# hoa (R$)                0.999955
# rent amount (R$)        1.000396
# property tax (R$)       0.999877
# fire insurance (R$)     0.970823
# no animals             -0.335946
# no furniture            0.230688

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
sns.distplot((y_test-predictions),bins=50);

# %%
lm.predict(X)
# Out:
# array([ 5618.03582287,  7972.81987851,  3841.31758063, ...,
#        19264.16899239,  7390.11607719, 14019.32215992])

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 0.6715374827654665
# MSE: 3.275465030621791
# RMSE: 1.8098245855943584

# %%
cb2.sort_values(by='total (R$)', ascending=False)
# Out:
#                  city  area  rooms  bathroom  parking spaces floor  hoa (R$)  \
# 2928   Rio de Janeiro    35      1         1               0     1     81150
# 1444     Porto Alegre    42      1         1               0    10     32000
# 6243   Rio de Janeiro    95      2         2               1    11      1024
# 6185        São Paulo   455      4         5               4     5      8500
# 1862        São Paulo   560      4         4               7     2      8600
# ...               ...   ...    ...       ...             ...   ...       ...
# 4868   Belo Horizonte    30      1         1               0     2         0
# 4294   Belo Horizonte    20      1         1               0     1         0
# 10218  Belo Horizonte    25      1         1               1     1         0
# 5876   Rio de Janeiro    30      1         1               1     3         0
# 9317   Rio de Janeiro    30      1         1               1     3         0
#
#        rent amount (R$)  property tax (R$)  fire insurance (R$)  total (R$)  \
# 2928               4500               9900                   58       95610
# 1444                700                 40                   11       32750
# 6243               3000              28120                   39       32180
# 6185              19500               3334                  248       31580
# 1862              15000               5000                  191       28790
# ...                 ...                ...                  ...         ...
# 4868                525                 25                    7         557
# 4294                500                 42                    7         549
# 10218               500                 38                    7         545
# 5876                500                  0                    7         507
# 9317                500                  0                    7         507
#
#        no animals  no furniture
# 2928            0             0
# 1444            0             1
# 6243            0             1
# 6185            0             1
# 1862            0             1
# ...           ...           ...
# 4868            0             1
# 4294            1             1
# 10218           1             1
# 5876            0             1
# 9317            0             1
#
# [8226 rows x 13 columns]

# %%
x=cb2.groupby(['city']).sum()
x
# Out:
#                   area  rooms  bathroom  parking spaces  hoa (R$)  \
# city
# Belo Horizonte  160973   2531      1982            1514    677491
# Campinas         70311   1386      1101             767    480526
# Porto Alegre     83382   1975      1563             863    560623
# Rio de Janeiro  138859   3065      2396            1010   1600418
# São Paulo       570914  10310      9899            7068   6247369
#
#                 rent amount (R$)  property tax (R$)  fire insurance (R$)  \
# city
# Belo Horizonte           2694538             232134                36164
# Campinas                 1257070              72697                16158
# Porto Alegre             2038635             102283                30251
# Rio de Janeiro           4428215             357793                57360
# São Paulo               19027179            1755970               241926
#
#                 total (R$)  no animals  no furniture
# city
# Belo Horizonte     3640669       259.0         781.0
# Campinas           1826462       134.0         552.0
# Porto Alegre       2731810       162.0         725.0
# Rio de Janeiro     6443802       282.0        1001.0
# São Paulo         27273752      1068.0        2916.0

# %%
b1 = pd.DataFrame({'city': ['Belo Horizonte','Campinas','Porto Alegre','Rio de Janeiro','São Paulo'],
                   'total (R$)':[3640669, 1826462, 2731810, 6443802, 27273752]})

# %%
import folium

# %%
b2= pd.DataFrame({'estado': ['MG','SP','RJ'],
                   'total (R$)':[3640669+2731810, 27273752+1826462, 6443802]})

# %%
b2
# Out:
#   estado  total (R$)
# 0     MG     6372479
# 1     SP    29100214
# 2     RJ     6443802

# %%
ufs= gpd.read_file('bcim_2016_21_11_2018.gpkg', layer='lim_unidade_federacao_a')

# %%
print('Estado:' + ufs.nome[2])
ufs.geometry[2]
# Out:
# Estado:Paraná

# %%
ufs.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   nome                 27 non-null     object
#  1   nomeabrev            0 non-null      object
#  2   geometriaaproximada  27 non-null     object
#  3   sigla                27 non-null     object
#  4   geocodigo            27 non-null     object
#  5   id_produtor          27 non-null     int64
#  6   id_elementoprodutor  0 non-null      object
#  7   cd_insumo_orgao      11 non-null     float64
#  8   nr_insumo_mes        0 non-null      object
#  9   nr_insumo_ano        0 non-null      object
#  10  tx_insumo_documento  0 non-null      object
#  11  geometry             27 non-null     geometry
# dtypes: float64(1), geometry(1), int64(1), object(9)
# memory usage: 2.7+ KB

# %%
ufs.rename({'sigla':'estado'}, axis=1,inplace=True)

# %%
ufs
# Out:
#                    nome nomeabrev geometriaaproximada estado geocodigo  \
# 0                 Goiás      None                 Sim     GO        52
# 1    Mato Grosso do Sul      None                 Sim     MS        50
# 2                Paraná      None                 Sim     PR        41
# 3          Minas Gerais      None                 Sim     MG        31
# 4               Sergipe      None                 Sim     SE        28
# 5               Alagoas      None                 Sim     AL        27
# 6             Tocantins      None                 Sim     TO        17
# 7               Roraima      None                 Sim     RR        14
# 8              Amazonas      None                 Sim     AM        13
# 9                  Acre      None                 Sim     AC        12
# 10             Rondônia      None                 Sim     RO        11
# 11     Distrito Federal      None                 Sim     DF        53
# 12                Piauí      None                 Sim     PI        22
# 13              Paraíba      None                 Sim     PB        25
# 14                Ceará      None                 Sim     CE        23
# 15       Santa Catarina      None                 Sim     SC        42
# 16       Rio de Janeiro      None                 Sim     RJ        33
# 17                Amapá      None                 Sim     AP        16
# 18                 Pará      None                 Sim     PA        15
# 19       Espírito Santo      None                 Sim     ES        32
# 20                Bahia      None                 Sim     BA        29
# 21          Mato Grosso      None                 Sim     MT        51
# 22           Pernambuco      None                 Sim     PE        26
# 23  Rio Grande do Norte      None                 Sim     RN        24
# 24             Maranhão      None                 Sim     MA        21
# 25            São Paulo      None                 Sim     SP        35
# 26    Rio Grande do Sul      None                 Sim     RS        43
#
#     id_produtor id_elementoprodutor  cd_insumo_orgao nr_insumo_mes  \
# 0       1000001                None              NaN          None
# 1       1000001                None              NaN          None
# 2       1000001                None              NaN          None
# 3       1000001                None              NaN          None
# 4       1000001                None              NaN          None
# 5       1000001                None              NaN          None
# 6       1000001                None              NaN          None
# 7       1000001                None              NaN          None
# 8       1000001                None              NaN          None
# 9       1000001                None              NaN          None
# 10      1000001                None              NaN          None
# 11      1000001                None              NaN          None
# 12      1000001                None              NaN          None
# 13      1000001                None             73.0          None
# 14      1000001                None             73.0          None
# 15      1000001                None             73.0          None
# 16      1000001                None             73.0          None
# 17      1000001                None              NaN          None
# 18      1000001                None             73.0          None
# 19      1000001                None             73.0          None
# 20      1000001                None              NaN          None
# 21      1000001                None             73.0          None
# 22      1000001                None             73.0          None
# 23      1000001                None             73.0          None
# 24      1000001                None             73.0          None
# 25      1000001                None             73.0          None
# 26      1000001                None              NaN          None
#
#    nr_insumo_ano tx_insumo_documento  \
# 0           None                None
# 1           None                None
# 2           None                None
# 3           None                None
# 4           None                None
# 5           None                None
# 6           None                None
# 7           None                None
# 8           None                None
# 9           None                None
# 10          None                None
# 11          None                None
# 12          None                None
# 13          None                None
# 14          None                None
# 15          None                None
# 16          None                None
# 17          None                None
# 18          None                None
# 19          None                None
# 20          None                None
# 21          None                None
# 22          None                None
# 23          None                None
# 24          None                None
# 25          None                None
# 26          None                None
#
#                                              geometry
# 0   MULTIPOLYGON (((-50.15876 -12.41581, -50.15743...
# 1   MULTIPOLYGON (((-56.09815 -17.17220, -56.09159...
# 2   MULTIPOLYGON (((-52.08090 -22.52893, -52.04903...
# 3   MULTIPOLYGON (((-44.21152 -14.22955, -44.20750...
# 4   MULTIPOLYGON (((-38.00366 -9.51544, -38.00052 ...
# 5   MULTIPOLYGON (((-35.45878 -8.81780, -35.45898 ...
# 6   MULTIPOLYGON (((-48.34644 -5.17871, -48.34311 ...
# 7   MULTIPOLYGON (((-60.17793 5.23024, -60.16619 5...
# 8   MULTIPOLYGON (((-67.32285 2.04176, -67.29220 1...
# 9   MULTIPOLYGON (((-73.73811 -7.13471, -72.90246 ...
# 10  MULTIPOLYGON (((-62.79892 -8.02312, -62.78622 ...
# 11  MULTIPOLYGON (((-47.94846 -15.49916, -47.91366...
# 12  MULTIPOLYGON (((-41.73344 -2.81111, -41.73205 ...
# 13  MULTIPOLYGON (((-37.21443 -6.03725, -37.20704 ...
# 14  MULTIPOLYGON (((-40.42389 -2.81130, -40.41525 ...
# 15  MULTIPOLYGON (((-48.63761 -25.97490, -48.63504...
# 16  MULTIPOLYGON (((-41.70343 -22.42014, -41.70380...
# 17  MULTIPOLYGON (((-51.18178 3.90573, -51.13631 3...
# 18  MULTIPOLYGON (((-46.25020 -1.13999, -46.25285 ...
# 19  MULTIPOLYGON (((-40.47978 -17.91795, -40.46958...
# 20  MULTIPOLYGON (((-38.97119 -8.78270, -38.95972 ...
# 21  MULTIPOLYGON (((-60.10041 -12.91271, -60.09773...
# 22  MULTIPOLYGON (((-32.38846 -3.81629, -32.39054 ...
# 23  MULTIPOLYGON (((-35.20267 -5.74677, -35.20324 ...
# 24  MULTIPOLYGON (((-42.03760 -2.70322, -42.04097 ...
# 25  MULTIPOLYGON (((-45.01051 -23.76176, -45.01624...
# 26  MULTIPOLYGON (((-53.03425 -27.15455, -53.03079...

# %%
Cp= ufs.merge(b2,on= 'estado', how='left')

# %%
Cp.plot(column='total (R$)',
       cmap='coolwarm',
       figsize=(5,5),
       legend= True,
       edgecolor='White')
